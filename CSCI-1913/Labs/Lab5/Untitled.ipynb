# %%
import numpy as np
import matplotlib.pyplot as plt 
import pandas as pd

# %%
backwards = pd.read_csv('backwards.csv')
backwards = backwards.to_numpy()
near_sorted = pd.read_csv('near_sorted.csv')
near_sorted = near_sorted.to_numpy()
random = pd.read_csv('random.csv')
random = random.to_numpy()
sorted_list = pd.read_csv('sorted_list.csv')
sorted_list = sorted_list.to_numpy()

# %%
backwards.shape
# Out:
# (83, 4)

# %%
x.shape,y.shape
# Out:
# ((83,), (83,))

# %%
# selection, insertion, merge
x = random[:,0]
y_select = random[:,1]
y_insert = random[:,2]
y_merge = random[:,3]
plt.plot(x,y_select,label="selction sort")
plt.plot(x,y_insert,label="insertion sort")
plt.plot(x,y_merge,label="merge sort")
plt.legend()

# %%
fig, ax=plt.subplots(nrows=2,ncols=2, figsize=(10,5))

# random

x = random[:,0]
y_select = random[:,1]
y_insert = random[:,2]
y_merge = random[:,3]
ax[0,0].plot(x,y_select,label="selction sort")
ax[0,0].plot(x,y_insert,label="insertion sort")
ax[0,0].plot(x,y_merge,label="merge sort")
ax[0,0].legend()
ax[0,0].set_title("random")

#each axes has it's own labels, title, legend.

# ax[0].legend()


# near_sorted
x = near_sorted[:,0]
y_select = near_sorted[:,1]
y_insert = near_sorted[:,2]
y_merge = near_sorted[:,3]
ax[0,1].plot(x,y_select,label="selction sort")
ax[0,1].plot(x,y_insert,label="insertion sort")
ax[0,1].plot(x,y_merge,label="merge sort")
ax[0,1].legend()
ax[0,1].set_title("near_sorted")


#sorted
x = sorted_list[:,0]
y_select = sorted_list[:,1]
y_insert = sorted_list[:,2]
y_merge = sorted_list[:,3]
# ax[1,0].plot(x,y_select,label="selction sort")
ax[1,0].plot(x,y_insert,label="insertion sort")
ax[1,0].plot(x,y_merge,label="merge sort")
ax[1,0].legend()
ax[1,0].set_title("sorted")


# backwards
x = backwards[:,0]
y_select = backwards[:,1]
y_insert = backwards[:,2]
y_merge = backwards[:,3]
ax[1,1].plot(x,y_select,label="selction sort")
ax[1,1].plot(x,y_insert,label="insertion sort")
ax[1,1].plot(x,y_merge,label="merge sort")
ax[1,1].legend()
ax[1,1].set_title("backwards")
plt.tight_layout()
# ax[0,1].set_xlabel('x')
# ax[0,1].set_ylabel('y')

# %%
import matplotlib.pyplot as plt
import numpy as np

# random
plt.subplot(2, 2, 1)
plt.plot(x,y)
x = random[:,0]
y_select = random[:,1]
y_insert = random[:,2]
y_merge = random[:,3]
plt.plot(x,y_select,label="selction sort")
plt.plot(x,y_insert,label="insertion sort")
plt.plot(x,y_merge,label="merge sort")
plt.legend()
plt.title("random")



# near_sorted
plt.subplot(2, 2, 2)
plt.plot(x,y)
x = near_sorted[:,0]
y_select = near_sorted[:,1]
y_insert = near_sorted[:,2]
y_merge = near_sorted[:,3]
plt.plot(x,y_select,label="selction sort")
plt.plot(x,y_insert,label="insertion sort")
plt.plot(x,y_merge,label="merge sort")
plt.legend()
plt.title("near_sorted")


# sorted list
plt.subplot(2, 2, 3)
plt.plot(x,y)
x = sorted_list[:,0]
y_select = sorted_list[:,1]
y_insert = sorted_list[:,2]
y_merge = sorted_list[:,3]
plt.plot(x,y_select,label="selction sort")
plt.plot(x,y_insert,label="insertion sort")
plt.plot(x,y_merge,label="merge sort")
plt.legend()
plt.title("sorted_list")


# backwards
plt.subplot(2, 2, 4)
plt.plot(x,y)
x = backwards[:,0]
y_select = backwards[:,1]
y_insert = backwards[:,2]
y_merge = backwards[:,3]
plt.plot(x,y_select,label="selction sort")
plt.plot(x,y_insert,label="insertion sort")
plt.plot(x,y_merge,label="merge sort")
plt.legend()
plt.title("backwards")
plt.tight_layout()

plt.show()
